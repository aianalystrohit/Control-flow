# %%
  #1. Write a Python program to check if a given number is positive or negative.  
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  1
# Positive

# %%
#2. Create a program that determines if a person is eligible to vote based on their age.  
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %%
#3. Develop a program to find the maximum of two numbers using if-else statements.  
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

if num1 > num2:
    print(num1, "is the maximum")
else:
    print(num2, "is the maximum")

# %%
#4. Write a Python script to classify a given year as a leap year or not.  
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year, "is a leap year")
else:
    print(year, "is not a leap year")

# %%
#5. Create a program that checks whether a character is a vowel or a consonant.  
char = input("Enter a character: ")

if char.lower() in 'aeiou':
    print(char, "is a vowel")
else:
    print(char, "is a consonant")

# %%
#6. Implement a program to determine whether a given number is even or odd.  
num = int(input("Enter a number: "))

if num % 2 == 0:
    print(num, "is even")
else:
    print(num, "is odd")

# %%
#7. Write a Python function to calculate the absolute value of a number without using the `abs()` function.  
def absolute_value(num):
    if num >= 0:
        return num
    else:
        return -num

num = int(input("Enter a number: "))
print("Absolute value:", absolute_value(num))

# %%
#8. Develop a program that determines the largest of three given numbers using if-else statements.  
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3

print(largest, "is the largest")

# %%
#9. Create a program that checks if a given string is a palindrome.  
string = input("Enter a string: ")

if string == string[::-1]:
    print(string, "is a palindrome")
else:
    print(string, "is not a palindrome")

# %%
#10. Write a Python program to calculate the grade based on a student's score.    
#Nested If-Else Statements:    
score = float(input("Enter your score: "))

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

print("Your grade is:", grade)

# %%
#11. Write a program to find the largest among three numbers using nested if-else statements.  
def find_largest(num1, num2, num3):
    if num1 >= num2 and num1 >= num3:
        return num1
    elif num2 >= num3:
        return num2
    else:
        return num3

# %%
#12. Implement a program to determine if a triangle is equilateral, isosceles, or scalene.  
def triangle_type(side1, side2, side3):
    if side1 == side2 == side3:
        return "Equilateral"
    elif side1 == side2 or side2 == side3 or side1 == side3:
        return "Isosceles"
    else:
        return "Scalene"

# %%
#13. Develop a program that checks if a year is a leap year and also if it is a century year.  
def is_leap_year(year):
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False

# %%
#14. Write a Python script to determine if a number is positive, negative, or zero. 
def check_number(num):
    if num > 0:
        return "Positive"
    elif num < 0:
        return "Negative"
    else:
        return "Zero"

# %%
#15. Create a program to check if a person is a teenager (between 13 and 19 years old).  
def is_teenager(age):
    return 13 <= age <= 19

# %%
#16. Develop a program that determines the type of angle based on its measure (acute, obtuse, or right).  
def angle_type(angle):
    if 0 < angle < 90:
        return "Acute"
    elif angle == 90:
        return "Right"
    elif 90 < angle < 180:
        return "Obtuse"
    else:
        return "Invalid angle"

# %%
#17. Write a Python program to calculate the roots of a quadratic equation.  
import math

def quadratic_roots(a, b, c):
    discriminant = b**2 - 4*a*c

    if discriminant > 0:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        return root1, root2
    elif discriminant == 0:
        root = -b / (2*a)
        return root, root
    else:
        return None

# %%
#18. Implement a program to determine the day of the week based on a user-provided number (1 for Monday, 2 for Tuesday, etc.).  
def day_of_week(num):
    days_of_week = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

    if 1 <= num <= 7:
        return days_of_week[num - 1]
    else:
        return "Invalid day number"

# %%
#19. Create a program that determines if a year is a leap year and also if it is evenly divisible by 400.  
def is_leap_year(year):
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False

# %%
#20. Develop a program that checks if a given number is prime or not using nested if-else statements.   
def is_prime(num):
    if num <= 1:
        return False
    if num <= 3:
        return True
    if num % 2 == 0 or num % 3 == 0:
        return False

    i = 5
    while i * i <= num:
        if num % i == 0 or num % (i + 2) == 0:
            return False
        i += 6

    return True

# %%
def assign_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

# %%
def assign_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

# %%
def bmi_category(weight, height):
    bmi = weight / (height * height)
    if bmi < 18.5:
        return "Underweight"
    elif bmi < 25:
        return "Normal"
    elif bmi < 30:
        return "Overweight"
    else:
        return "Obese"

# %%
def check_number(num):
    if num > 0:
        return "Positive"
    elif num < 0:
        return "Negative"
    else:
        return "Zero"

# %%
def character_type(char):
    if char.isupper():
        return "Uppercase"
    elif char.islower():
        return "Lowercase"
    else:
        return "Special"

# %%
def calculate_discount(purchase_amount):
    if purchase_amount >= 10000:
        discount = 0.15
    elif purchase_amount >= 5000:
        discount = 0.10
    elif purchase_amount >= 2000:
        discount = 0.05
    else:
        discount = 0
    discounted_price = purchase_amount - (purchase_amount * discount)
    return discounted_price

# %%
def calculate_electricity_bill(units_consumed):
    if units_consumed <= 100:
        rate = 3.5
    elif units_consumed <= 200:
        rate = 4.5
    elif units_consumed <= 300:
        rate = 5.5
    else:
        rate = 6.5
    bill = units_consumed * rate
    return bill

# %%
def quadrilateral_type(angles):
    if all(angle == 90 for angle in angles):
        return "Rectangle"
    elif all(angle == 90 for angle in angles) and all(side == angles[0] for side in angles):
        return "Square"
    elif sum(angles) == 360 and all(angle > 0 and angle < 180 for angle in angles):
        return "Trapezoid"
    else:
        return "Invalid angles"

# %%
def determine_season(month):
    if month in ["March", "April", "May"]:
        return "Spring"
    elif month in ["June", "July", "August"]:
        return "Summer"
    elif month in ["September", "October", "November"]:
        return "Autumn"
    else:
        return "Winter"

# %%
def year_month_type(year, month):
    if month in [4, 6, 9, 11]:
        return "Leap year" if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0) else "Common year", 30
    elif month == 2:
        return "Leap year" if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0) else "Common year", 28 if not is_leap_year(year) else 29
    else:
        return "Common year", 31

# %%
# 1. Check if a number is positive, negative, or zero
def check_number(num):
    if num > 0:
        print("The number is positive.")
    elif num < 0:
        print("The number is negative.")
    else:
        print("The number is zero.")

# 2. Check if a person is eligible to vote
def check_voting_eligibility(age):
    if age >= 18:
        print("You are eligible to vote.")
    else:
        print("You are not eligible to vote.")

# 3. Find the maximum of two numbers
def find_maximum(num1, num2):
    if num1 > num2:
        print(num1, "is the maximum.")
    else:
        print(num2, "is the maximum.")

# 4. Calculate the grade of a student
def calculate_grade(score):
    if score >= 90:
        print("Grade: A")
    elif score >= 80:
        print("Grade: B")
    elif score >= 70:
        print("Grade: C")
    elif score >= 60:
        print("Grade: D")
    else:
        print("Grade: F")

# 5. Check if a year is a leap year
def is_leap_year(year):
    if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
        print("It is a leap year.")
    else:
        print("It is not a leap year.")

# 6. Classify a triangle based on sides' lengths
def classify_triangle(side1, side2, side3):
    if side1 == side2 == side3:
        print("Equilateral triangle")
    elif side1 == side2 or side2 == side3 or side1 == side3:
        print("Isosceles triangle")
    else:
        print("Scalene triangle")

# 7. Find the largest of three numbers
def find_largest(num1, num2, num3):
    largest = num1
    if num2 > largest:
        largest = num2
    if num3 > largest:
        largest = num3
    print(largest, "is the largest.")

# 8. Check if a character is a vowel or a consonant
def vowel_or_consonant(char):
    vowels = "aeiouAEIOU"
    if char in vowels:
        print("It is a vowel.")
    else:
        print("It is a consonant.")

# 9. Calculate the total cost of a shopping cart
def calculate_total_cost(items, prices, discounts):
    total = 0
    for i in range(len(items)):
        total += (prices[i] * (1 - discounts[i]))
    print("Total cost:", total)

# 10. Check if a number is even or odd
def is_even_or_odd(num):
    if num % 2 == 0:
        print("The number is even.")
    else:
        print("The number is odd.")

# Example usage:
check_number(5)
check_voting_eligibility(17)
find_maximum(10, 20)
calculate_grade(85)
is_leap_year(2024)
classify_triangle(3, 3, 3)
find_largest(10, 20, 5)
vowel_or_consonant("a")
calculate_total_cost(["item1", "item2"], [10, 20], [0.1, 0.2])
is_even_or_odd(7)
# Out:
# The number is positive.
# You are not eligible to vote.
# 20 is the maximum.
# Grade: B
# It is a leap year.
# Equilateral triangle
# 20 is the largest.
# It is a vowel.
# Total cost: 25.0
# The number is odd.

# %%
import math

def quadratic_roots(a, b, c):
    discriminant = b**2 - 4*a*c

    if discriminant > 0:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        return root1, root2
    elif discriminant == 0:
        root = -b / (2*a)
        return root, root
    else:
        return None

# %%
def day_of_week(day_number):
    days_of_week = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

    if 1 <= day_number <= 7:
        return days_of_week[day_number - 1]
    else:
        return "Invalid day number"

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

# %%
def find_largest(num1, num2, num3):
    if num1 >= num2 and num1 >= num3:
        return num1
    elif num2 >= num3:
        return num2
    else:
        return num3

# %%
def find_largest(num1, num2, num3):
    if num1 >= num2 and num1 >= num3:
        return num1
    elif num2 >= num3:
        return num2
    else:
        return num3

# %%
def is_palindrome(string):
    return string == string[::-1]

# %%
def is_palindrome(string):
    return string == string[::-1]

# %%
def is_palindrome(string):
    return string == string[::-1]

# %%
def basic_calculator():
    while True:
        print("Choose an operation:")
        print("1. Addition")
        print("2. Subtraction")
        print("3. Multiplication")
        print("4. Division")
        print("5. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            result = num1 + num2
            print("Result:", result)
        elif choice == 2:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            result = num1 - num2
            print("Result:", result)
        elif choice == 3:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            result = num1 * num2
            print("Result:", result)
        elif choice == 4:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
            if num2 == 0:
                print("Error: Division by zero is not allowed.")
            else:
                result = num1 / num2
                print("Result:", result)
        elif choice == 5:
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please try again.")

basic_calculator()
# Out:
# Choose an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice:  1
# Enter the first number:  2
# Enter the second number:  3
# Result: 5.0
# Choose an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice:  4
# Enter the first number:  3

# %%
import math

def cubic_roots(a, b, c, d):
    # Handle special case: cubic equation with no cubic term
    if a == 0:
        return quadratic_roots(b, c, d)

    # Calculate discriminant
    discriminant = 18*a*b*c*d - 27*a**2*d**2 - 4*a**3*c**3 - 4*b**3*d + b**2*c**2

    if discriminant > 0:
        # Three real roots
        p = (3*a*c - b**2) / (3*a**2)
        q = (2*b**3 - 9*a*b*c + 27*a**2*d) / (27*a**3)
        delta = q**2 / 4 + p**3 / 27
        u = math.pow(math.sqrt(delta) + q/2, 1/3)
        v = math.pow(-math.sqrt(delta) + q/2, 1/3)
        root1 = u + v - b/(3*a)
        root2 = -0.5*(u + v) + 0.5*math.sqrt(-3)*(u - v) - b/(3*a)
        root3 = -0.5*(u + v) - 0.5*math.sqrt(-3)*(u - v) - b/(3*a)
        return root1, root2, root3
    elif discriminant == 0:
        # Three real roots, at least two of which are equal
        p = (3*a*c - b**2) / (3*a**2)
        q = (2*b**3 - 9*a*b*c + 27*a**2*d) / (27*a**3)
        u = math.pow(q/2, 1/3)
        root1 = 3*u - b/(3*a)
        root2 = -2*u - b/(3*a)
        root3 = root2
        return root1, root2, root3
    else:
        # One real root and two complex conjugate roots
        # ... (implementation omitted for brevity)
        return None

# Example usage:
a, b, c, d = 1, -6, 11, -6
roots = cubic_roots(a, b, c, d)
print("Roots:", roots)

# %%
def calculate_income_tax(income):
    # Replace with your specific tax brackets and rates
    tax_brackets = [(0, 250000), (250000, 500000), (500000, 1000000)]
    tax_rates = [0.05, 0.10, 0.15]

    taxable_income = income

    for i in range(len(tax_brackets)):
        bracket_start, bracket_end = tax_brackets[i]
        bracket_width = bracket_end - bracket_start
        if taxable_income > bracket_end:
            tax = tax_rates[i] * bracket_width
            taxable_income -= bracket_width
        else:
            tax = tax_rates[i] * (taxable_income - bracket_start)
            break

    return tax

# Example usage:
income = 350000
income_tax = calculate_income_tax(income)
print("Income Tax:", income_tax)

# %%
import random

def rock_paper_scissors():
    choices = ["rock", "paper", "scissors"]

    while True:
        user_choice = input("Enter your choice (rock, paper, scissors): ").lower()

        if user_choice not in choices:
            print("Invalid choice. Please try again.")
            continue

        computer_choice = random.choice(choices)

        print("Computer chose:", computer_choice)

        if user_choice == computer_choice:
            print("It's a tie!")
        elif (user_choice == "rock" and computer_choice == "scissors") or \
             (user_choice == "paper" and computer_choice == "rock") or \
             (user_choice == "scissors" and computer_choice == "paper"):
            print("You win!")
        else:
            print("Computer wins!")

        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again != "yes":
            break

rock_paper_scissors()

# %%
import random
import string

def generate_password(length, include_uppercase=True, include_lowercase=True, include_numbers=True, include_symbols=True):
    characters = ""

    if include_uppercase:
        characters += string.ascii_uppercase
    if include_lowercase:
        characters += string.ascii_lowercase
    if include_numbers:
        characters += string.digits
    if include_symbols:
        characters += string.punctuation

    password = ''.join(random.choice(characters) for _ in range(length))
    return password

# Example usage:
password = generate_password(12, True, True, True, True)
print("Generated password:", password)

# %%
def adventure_game():
    print("Welcome to the adventure game!")

    # ... implement game logic with branching scenarios

adventure_game()

# %%
def solve_linear_equation(a, b):
    if a == 0:
        if b == 0:
            print("Infinite solutions")
        else:
            print("No solution")
    else:
        x = -b / a
        print("Solution: x =", x)

# %%
def quiz_game():
    questions = [
        {"question": "What is the capital of India?", "options": ["Delhi", "Mumbai", "Kolkata", "Chennai"], "answer": "Delhi"},
        # ... add more questions
    ]

    score = 0

    for question in questions:
        print(question["question"])
        for i, option in enumerate(question["options"]):
            print(f"{i+1}. {option}")

        user_answer = int(input("Enter your answer (1-4): ")) - 1

        if user_answer == question["options"].index(question["answer"]):
            print("Correct!")
            score += 1
        else:
            print("Incorrect. The correct answer is:", question["answer"])

    print("Your final score:", score)

quiz_game()

# %%
def quiz_game():
    questions = [
        {"question": "What is the capital of India?", "options": ["Delhi", "Mumbai", "Kolkata", "Chennai"], "answer": "Delhi"},
        # ... add more questions
    ]

    score = 0

    for question in questions:
        print(question["question"])
        for i, option in enumerate(question["options"]):
            print(f"{i+1}. {option}")

        user_answer = int(input("Enter your answer (1-4): ")) - 1

        if user_answer == question["options"].index(question["answer"]):
            print("Correct!")
            score += 1
        else:
            print("Incorrect. The correct answer is:", question["answer"])

    print("Your final score:", score)

quiz_game()

# %%
def quiz_game():
    questions = [
        {"question": "What is the capital of India?", "options": ["Delhi", "Mumbai", "Kolkata", "Chennai"], "answer": "Delhi"},
        # ... add more questions
    ]

    score = 0

    for question in questions:
        print(question["question"])
        for i, option in enumerate(question["options"]):
            print(f"{i+1}. {option}")

        user_answer = int(input("Enter your answer (1-4): ")) - 1

        if user_answer == question["options"].index(question["answer"]):
            print("Correct!")
            score += 1
        else:
            print("Incorrect. The correct answer is:", question["answer"])

    print("Your final score:", score)

quiz_game()

# %%
def calculate_bmi(weight_kg, height_m):
    bmi = weight_kg / (height_m ** 2)
    return bmi

def get_bmi_category(bmi):
    if bmi < 18.5:
        return "Underweight"
    elif bmi < 25:
        return "Normal"
    elif bmi < 30:
        return "Overweight"
    else:
        return "Obese"

# Example usage:
weight_kg = 70
height_m = 1.75
bmi = calculate_bmi(weight_kg, height_m)
bmi_category = get_bmi_category(bmi)
print("BMI:", bmi)
print("BMI Category:", bmi_category)

# %%
def validate_password(password):
    if len(password) < 8:
        return False

    has_uppercase = False
    has_lowercase = False
    has_digit = False
    has_special_char = False

    for char in password:
        if char.isupper():
            has_uppercase = True
        elif char.islower():
            has_lowercase = True
        elif char.isdigit():
            has_digit = True
        elif not char.isalnum():
            has_special_char = True

    return has_uppercase and has_lowercase and has_digit and has_special_char

# Example usage:
password = "Password123#"
if validate_password(password):
    print("Password is valid.")
else:
    print("Password is invalid.")

# %%
def add_matrices(matrix1, matrix2):
    rows = len(matrix1)
    cols = len(matrix1[0])

    result = [[0 for _ in range(cols)] for _ in range(rows)]

    for i in range(rows):
        for j in range(cols):
            result[i][j] = matrix1[i][j] + matrix2[i][j]

    return result

def subtract_matrices(matrix1, matrix2):
    rows = len(matrix1)
    cols = len(matrix1[0])

    result = [[0 for _ in range(cols)] for _ in range(rows)]

    for i in range(rows):
        for j in range(cols):
            result[i][j] = matrix1[i][j] - matrix2[i][j]

    return result

# Example usage:
matrix1 = [[1, 2], [3, 4]]
matrix2 = [[5, 6], [7, 8]]

sum_matrix = add_matrices(matrix1, matrix2)
difference_matrix = subtract_matrices(matrix1, matrix2)

print("Sum matrix:")
print(sum_matrix)

print("Difference matrix:")
print(difference_matrix)

# %%
def add_matrices(matrix1, matrix2):
    rows = len(matrix1)
    cols = len(matrix1[0])

    result = [[0 for _ in range(cols)] for _ in range(rows)]

    for i in range(rows):
        for j in range(cols):
            result[i][j] = matrix1[i][j] + matrix2[i][j]

    return result

def subtract_matrices(matrix1, matrix2):
    rows = len(matrix1)
    cols = len(matrix1[0])

    result = [[0 for _ in range(cols)] for _ in range(rows)]

    for i in range(rows):
        for j in range(cols):
            result[i][j] = matrix1[i][j] - matrix2[i][j]

    return result

# Example usage:
matrix1 = [[1, 2], [3, 4]]
matrix2 = [[5, 6], [7, 8]]

sum_matrix = add_matrices(matrix1, matrix2)
difference_matrix = subtract_matrices(matrix1, matrix2)

print("Sum matrix:")
print(sum_matrix)

print("Difference matrix:")
print(difference_matrix)

# %%
def gcd(a, b):
    while b != 0:
        a, b = b, a % b
    return a

# Example usage:
num1 = 12
num2 = 18
gcd_value = gcd(num1, num2)
print("GCD:", gcd_value)

# %%
def multiply_matrices(matrix1, matrix2):
    rows1 = len(matrix1)
    cols1 = len(matrix1[0])
    rows2 = len(matrix2)
    cols2 = len(matrix2[0])

    if cols1 != rows2:
        print("Matrix multiplication not possible. Incompatible dimensions.")
        return None

    result = [[0 for _ in range(cols2)] for _ in range(rows1)]

    for i in range(rows1):
        for j in range(cols2):
            for k in range(cols1):
                result[i][j] += matrix1[i][k] * matrix2[k][j]

    return result

# Example usage:
matrix1 = [[1, 2], [3, 4]]
matrix2 = [[5, 6], [7, 8]]

product_matrix = multiply_matrices(matrix1, matrix2)

print("Product matrix:")
print(product_matrix)

# %%
def tic_tac_toe():
    board = ["-" for _ in range(9)]

    def print_board():
        print(board[0] + "|" + board[1] + "|" + board[2])
        print("---")
        print(board[3] + "|" + board[4] + "|" + board[5])
        print("---")
        print(board[6] + "|" + board[7] + "|" + board[8])

    def check_win(player):
        winning_combinations = [
            (0, 1, 2), (3, 4, 5), (6, 7, 8),  # Rows
            (0, 3, 6), (1, 4, 7), (2, 5, 8),  # Columns
            (0, 4, 8), (2, 4, 6)  # Diagonals
        ]

        for combination in winning_combinations:
            if board[combination[0]] == board[combination[1]] == board[combination[2]] == player:
                return True
        return False

    def is_board_full():
        return all(cell != "-" for cell in board)

    player = "X"
    while True:
        print_board()

        move = int(input("Enter your move (1-9): ")) - 1

        if board[move] == "-":
            board[move] = player
            if check_win(player):
                print_board()
                print(player, "wins!")
                break
            if is_board_full():
                print_board()
                print("It's a tie!")
                break
            player = "O" if player == "X" else "X"
        else:
            print("Invalid move. Please try again.")

tic_tac_toe()

# %%
def generate_fibonacci(n):
    if n <= 0:
        return []

    fib_sequence = [0, 1]
    for i in range(2, n):
        fib_sequence.append(fib_sequence[i-1] + fib_sequence[i-2])

    return fib_sequence

# Example usage:
n = 10
fibonacci_numbers = generate_fibonacci(n)
print(fibonacci_numbers)

# %%
def fibonacci_memo(n, memo={}):
    if n in memo:
        return memo[n]
    if n <= 1:
        return n
    memo[n] = fibonacci_memo(n-1, memo) + fibonacci_memo(n-2, memo)
    return memo[n]

# Example usage:
n = 10
fibonacci_number = fibonacci_memo(n)
print(fibonacci_number)

# %%
import calendar

def generate_calendar(year, month):
    print(calendar.month(year, month))

# Example usage:
year = 2023
month = 12
generate_calendar(year, month)

# %%
import calendar

def generate_calendar(year, month):
    print(calendar.month(year, month))

# Example usage:
year = 2023
month = 12
generate_calendar(year, month)
